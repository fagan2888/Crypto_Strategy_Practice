# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import math
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

import seaborn as sns

# %matplotlib inline

# %%
from crycompare import *

# %% [markdown]
# ### Get list of all coins

# %%
p = Price()

coinList = p.coinList()
coins = sorted(list( coinList['Data'].keys() ))
coins[:5]
# Out:
# ['007', '1337', '1CR', '1ST', '2015']

# %%
# coins_to_check = ['BTC', 'ETH', 'LTC', 'ARK']
coins_to_check = ['BTC', 'ETH', 'LTC', 'ARK', 'XMR']
[x in coins for x in coins_to_check]
# Out:
# [True, True, True, True, True]

# %% [markdown]
# ### Get historical price data

# %%
h = History()

df_dict = {}
for coin in coins_to_check:
    histo = h.histoDay(coin,'USD',allData=True)
    if histo['Data']:
        df_histo = pd.DataFrame(histo['Data'])
        df_histo['time'] = pd.to_datetime(df_histo['time'],unit='s')
        df_histo.index = df_histo['time']
        del df_histo['time']
        del df_histo['volumefrom']
        del df_histo['volumeto']
        
        df_dict[coin] = df_histo

# %%
df = pd.DataFrame()
df['BTC'] = df_dict['BTC']['close']
for key, value in df_dict.items():
    if key == 'BTC':
        continue
    df[key] = value['close']

df.fillna(value=0, inplace=True)
df.tail()
# Out:
#                 BTC    LTC   ARK     XMR     ETH
# time
# 2017-09-16  3698.92  52.10  3.58   96.40  254.49
# 2017-09-17  3689.61  51.00  3.30   93.72  258.40
# 2017-09-18  4100.28  56.16  3.70  101.74  297.53
# 2017-09-19  3907.96  52.80  3.24   98.28  283.00
# 2017-09-20  3923.45  52.55  3.29   96.53  284.08

# %%
df_log = pd.DataFrame()
for coin in df.columns:
    df_log[coin] = np.diff(np.log(df[coin]))
    df_log[coin].replace(-np.Inf, 0, inplace=True)
    df_log[coin].replace(np.Inf, 0, inplace=True)

df_log.index = df.index[1:]
# df_log.fillna(value=0, inplace=True)
df_log.tail()
# Out:
#                  BTC       LTC       ARK       XMR       ETH
# time
# 2017-09-16 -0.004004  0.001921 -0.095818 -0.036764 -0.019765
# 2017-09-17 -0.002520 -0.021339 -0.081440 -0.028195  0.015247
# 2017-09-18  0.105535  0.096379  0.114410  0.082109  0.141006
# 2017-09-19 -0.048040 -0.061694 -0.132759 -0.034600 -0.050068
# 2017-09-20  0.003956 -0.004746  0.015314 -0.017967  0.003809

# %% [markdown]
# ### Plot log returns

# %%
df_log.plot(figsize=(14,5))
plt.xlabel('Time')
plt.ylabel('Log Return')

# %% [markdown]
# ### ADF Test to ensure stationarity
# p <= 0.05, reject null, the data doesn't have unit root and is stationary.

# %%
for col in df_log:
    result = adfuller(df_log[col].dropna())
    print('{}:'.format(col))
    print('\tADF Statistic: %f' % result[0])
    print('\tp-value: %f' % result[1])
    print('\tCritical Values:')
    for key, value in result[4].items():
        print('\t\t%s: %.3f' % (key, value))
# Out:
# BTC:
# 	ADF Statistic: -20.307851
# 	p-value: 0.000000
# 	Critical Values:
# 		5%: -2.863
# 		1%: -3.433
# 		10%: -2.567
# LTC:
# 	ADF Statistic: -12.520491
# 	p-value: 0.000000
# 	Critical Values:
# 		5%: -2.864
# 		1%: -3.435
# 		10%: -2.568
# ARK:
# 	ADF Statistic: -13.192691
# 	p-value: 0.000000
# 	Critical Values:
# 		5%: -2.878
# 		1%: -3.467
# 		10%: -2.575
# XMR:
# 	ADF Statistic: -8.480061
# 	p-value: 0.000000
# 	Critical Values:
# 		5%: -2.865
# 		1%: -3.437
# 		10%: -2.568
# ETH:
# 	ADF Statistic: -15.966791
# 	p-value: 0.000000
# 	Critical Values:
# 		5%: -2.865
# 		1%: -3.439
# 		10%: -2.569

# %%
for col in df_log.columns:
    acf = pd.DataFrame(sm.tsa.stattools.acf(df_log[col].dropna()), columns=[col])
    fig = acf[1:].plot(kind='bar', title='{} Autocorrelations'.format(col))
    print('{} acf mean: {}'.format(col, acf[1:].mean()))
# Out:
# BTC acf mean: BTC    0.006163
# dtype: float64
# LTC acf mean: LTC    0.002571
# dtype: float64
# ARK acf mean: ARK   -0.013214
# dtype: float64
# XMR acf mean: XMR   -0.01057
# dtype: float64
# ETH acf mean: ETH    0.00876
# dtype: float64

# %% [markdown]
# All stationary, so good.

# %%
corr_mtx = df_log.corr()
sns.heatmap(corr_mtx,annot=True)

# %%
df_log.dropna().head().replace(np.inf, 0)
# Out:
#                  BTC       LTC       ARK       XMR       ETH
# time
# 2017-03-22 -0.070731 -0.027263  0.000000 -0.055769 -0.024195
# 2017-03-23 -0.009318  0.010000  0.527910  0.076416  0.036539
# 2017-03-24 -0.096625  0.039029  0.128199 -0.018795  0.208030
# 2017-03-25  0.027914 -0.012034  0.308193 -0.090003 -0.049524
# 2017-03-26  0.003244 -0.007290 -0.184216 -0.043992  0.000198

# %%
df_log.dropna().tail().replace(np.inf, 0)
# Out:
#                  BTC       LTC       ARK       XMR       ETH
# time
# 2017-09-16 -0.004004  0.001921 -0.095818 -0.036764 -0.019765
# 2017-09-17 -0.002520 -0.021339 -0.081440 -0.028195  0.015247
# 2017-09-18  0.105535  0.096379  0.114410  0.082109  0.141006
# 2017-09-19 -0.048040 -0.061694 -0.132759 -0.034600 -0.050068
# 2017-09-20  0.003956 -0.004746  0.015314 -0.017967  0.003809

# %%
corr_mtx = df_log.dropna().replace(np.inf, 0).corr()
sns.heatmap(corr_mtx,annot=True)

# %% [markdown]
# ## Momentum strategy

# %%
df.head()
# Out:
#                 BTC  LTC  ARK  XMR  ETH
# time
# 2010-07-17  0.04951  0.0  0.0  0.0  0.0
# 2010-07-18  0.08584  0.0  0.0  0.0  0.0
# 2010-07-19  0.08080  0.0  0.0  0.0  0.0
# 2010-07-20  0.07474  0.0  0.0  0.0  0.0
# 2010-07-21  0.07921  0.0  0.0  0.0  0.0

# %%
df['BTC'].shift(1).head()
# Out:
# time
# 2010-07-17        NaN
# 2010-07-18    0.04951
# 2010-07-19    0.08584
# 2010-07-20    0.08080
# 2010-07-21    0.07474
# Name: BTC, dtype: float64

# %%
(df['BTC'] / df['BTC'].shift(1)).head()
# Out:
# time
# 2010-07-17         NaN
# 2010-07-18    1.733791
# 2010-07-19    0.941286
# 2010-07-20    0.925000
# 2010-07-21    1.059807
# Name: BTC, dtype: float64

# %%
cols = df.columns
for col in df.columns:
    ret_col = '{}_returns'.format(col)
    df[ret_col] = np.log(df[col] / df[col].shift(1))
    
df.head()
# Out:
#                 BTC  LTC  ARK  XMR  ETH  BTC_returns  LTC_returns  \
# time
# 2010-07-17  0.04951  0.0  0.0  0.0  0.0          NaN          NaN
# 2010-07-18  0.08584  0.0  0.0  0.0  0.0     0.550310          NaN
# 2010-07-19  0.08080  0.0  0.0  0.0  0.0    -0.060508          NaN
# 2010-07-20  0.07474  0.0  0.0  0.0  0.0    -0.077962          NaN
# 2010-07-21  0.07921  0.0  0.0  0.0  0.0     0.058087          NaN
#
#             ARK_returns  XMR_returns  ETH_returns
# time
# 2010-07-17          NaN          NaN          NaN
# 2010-07-18          NaN          NaN          NaN
# 2010-07-19          NaN          NaN          NaN
# 2010-07-20          NaN          NaN          NaN
# 2010-07-21          NaN          NaN          NaN

# %%
mom_array = [15, 30, 60, 120]

for col in cols: 
    for momentum in mom_array:
        pos_col = '{}_position_{}'.format(col, momentum)
        df[pos_col] = np.sign(df['{}_returns'.format(col)].rolling(window=momentum).mean())
    
df.tail()
# Out:
#                 BTC    LTC   ARK     XMR     ETH  BTC_returns  LTC_returns  \
# time
# 2017-09-16  3698.92  52.10  3.58   96.40  254.49    -0.004004     0.001921
# 2017-09-17  3689.61  51.00  3.30   93.72  258.40    -0.002520    -0.021339
# 2017-09-18  4100.28  56.16  3.70  101.74  297.53     0.105535     0.096379
# 2017-09-19  3907.96  52.80  3.24   98.28  283.00    -0.048040    -0.061694
# 2017-09-20  3923.45  52.55  3.29   96.53  284.08     0.003956    -0.004746
#
#             ARK_returns  XMR_returns  ETH_returns        ...         \
# time                                                     ...
# 2017-09-16    -0.095818    -0.036764    -0.019765        ...
# 2017-09-17    -0.081440    -0.028195     0.015247        ...
# 2017-09-18     0.114410     0.082109     0.141006        ...
# 2017-09-19    -0.132759    -0.034600    -0.050068        ...
# 2017-09-20     0.015314    -0.017967     0.003809        ...
#
#             ARK_position_60  ARK_position_120  XMR_position_15  \
# time
# 2017-09-16              1.0               1.0             -1.0
# 2017-09-17              1.0               1.0             -1.0
# 2017-09-18              1.0               1.0             -1.0
# 2017-09-19              1.0               1.0             -1.0
# 2017-09-20              1.0               1.0             -1.0
#
#             XMR_position_30  XMR_position_60  XMR_position_120  \
# time
# 2017-09-16              1.0              1.0               1.0
# 2017-09-17              1.0              1.0               1.0
# 2017-09-18              1.0              1.0               1.0
# 2017-09-19              1.0              1.0               1.0
# 2017-09-20              1.0              1.0               1.0
#
#             ETH_position_15  ETH_position_30  ETH_position_60  \
# time
# 2017-09-16             -1.0             -1.0              1.0
# 2017-09-17             -1.0             -1.0              1.0
# 2017-09-18             -1.0              1.0              1.0
# 2017-09-19             -1.0             -1.0              1.0
# 2017-09-20             -1.0             -1.0              1.0
#
#             ETH_position_120
# time
# 2017-09-16               1.0
# 2017-09-17               1.0
# 2017-09-18               1.0
# 2017-09-19               1.0
# 2017-09-20               1.0
#
# [5 rows x 30 columns]

# %%
for col in cols:
    strats = ['{}_returns'.format(col)]
    for mom in mom_array:
        strat = '{}_strategy_{}'.format(col, mom)
        df[strat] = df['{}_position_{}'.format(col, mom)].shift(1) * df['{}_returns'.format(col)]
        strats.append(strat)

    # apply np.exp to convert logs to arithmetic returns
    df[strats].dropna().cumsum().apply(np.exp).plot()
    
df.tail()
# Out:
#                 BTC    LTC   ARK     XMR     ETH  BTC_returns  LTC_returns  \
# time
# 2017-09-16  3698.92  52.10  3.58   96.40  254.49    -0.004004     0.001921
# 2017-09-17  3689.61  51.00  3.30   93.72  258.40    -0.002520    -0.021339
# 2017-09-18  4100.28  56.16  3.70  101.74  297.53     0.105535     0.096379
# 2017-09-19  3907.96  52.80  3.24   98.28  283.00    -0.048040    -0.061694
# 2017-09-20  3923.45  52.55  3.29   96.53  284.08     0.003956    -0.004746
#
#             ARK_returns  XMR_returns  ETH_returns        ...         \
# time                                                     ...
# 2017-09-16    -0.095818    -0.036764    -0.019765        ...
# 2017-09-17    -0.081440    -0.028195     0.015247        ...
# 2017-09-18     0.114410     0.082109     0.141006        ...
# 2017-09-19    -0.132759    -0.034600    -0.050068        ...
# 2017-09-20     0.015314    -0.017967     0.003809        ...
#
#             ARK_strategy_60  ARK_strategy_120  XMR_strategy_15  \
# time
# 2017-09-16        -0.095818         -0.095818         0.036764
# 2017-09-17        -0.081440         -0.081440         0.028195
# 2017-09-18         0.114410          0.114410        -0.082109
# 2017-09-19        -0.132759         -0.132759         0.034600
# 2017-09-20         0.015314          0.015314         0.017967
#
#             XMR_strategy_30  XMR_strategy_60  XMR_strategy_120  \
# time
# 2017-09-16        -0.036764        -0.036764         -0.036764
# 2017-09-17        -0.028195        -0.028195         -0.028195
# 2017-09-18         0.082109         0.082109          0.082109
# 2017-09-19        -0.034600        -0.034600         -0.034600
# 2017-09-20        -0.017967        -0.017967         -0.017967
#
#             ETH_strategy_15  ETH_strategy_30  ETH_strategy_60  \
# time
# 2017-09-16         0.019765         0.019765        -0.019765
# 2017-09-17        -0.015247        -0.015247         0.015247
# 2017-09-18        -0.141006        -0.141006         0.141006
# 2017-09-19         0.050068        -0.050068        -0.050068
# 2017-09-20        -0.003809        -0.003809         0.003809
#
#             ETH_strategy_120
# time
# 2017-09-16         -0.019765
# 2017-09-17          0.015247
# 2017-09-18          0.141006
# 2017-09-19         -0.050068
# 2017-09-20          0.003809
#
# [5 rows x 50 columns]

# %% [markdown]
# - BTC gets big bump from momentum over returns, with best at 15 day.
# - LTC momentum outperforms, with best at 120 day. Makes sense since LTC is slowest moving among the coins.
# - ARK has such little price data, hard to make strong conclusions.
# - XMR momentum is garbage.
# - ETH returns alone perform better, but the 15 day strategy does well to avoid the large drawdown recently
